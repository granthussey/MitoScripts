# %%
import pandas as pd
import numpy as np
import glob 
import igraph as gr
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.17</span>
#         </div>

# %% [markdown]
# Get filenames from list(dfs.keys())
# Get paths using get_xxx_paths
# Get dfs using get_xxx_dfs

# %%
def remove_path(full_path):
    
    if full_path.find('/') == -1:
        pass
        
    if full_path.find('/') != -1:
        filename = full_path.split("/")[-1]
        
    return(filename)

# %%
def get_filename(path_or_filename_with_extension):
    # This will fail if more than one . is in the file, such as ".tar.gz"
    
    cur_filename_with_extension = remove_path(path_or_filename_with_extension)
    
    noExtension = cur_filename_with_extension.split(".")[0]
    
    return(noExtension)

# %%
def get_gnet_paths(dir):
    gnet_filename_list = []
    gnet_path_list = []

    for ipath in glob.glob(data_dir + '/*.gnet'):

        gnet_path_list.append(ipath)
        gnet_filename_list.append(get_filename(ipath))
         
    return gnet_path_list

# %%
def get_gnet_dfs(dir):

    gnet_dfs = {}
    total_nodes = {}
    
    gnet_path_list = get_gnet_paths(dir)

    for ignet_paths in gnet_path_list:

        cur_filename = get_filename(ignet_paths) 

        gnet_dfs[cur_filename] = pd.read_csv(ignet_paths,sep='\t').reset_index()

        total_nodes[cur_filename] = int(gnet_dfs[cur_filename].columns[2])

        gnet_dfs[cur_filename] = gnet_dfs[cur_filename].rename(columns = {'level_0':'Source','level_1':'Target',str(total_nodes[cur_filename]):'Length'})

    
    return gnet_dfs

# %%
def get_edge_list_from_df(df):
    
    uncleaned_edges = df.values[:,[0,1]]
    
    edge_list = []

    for iter_edges in uncleaned_edges:    
        
        cur_element = [int(iter_edges[0]), int(iter_edges[1])]
        
        edge_list.append(cur_element)

    return edge_list

# %%
def create_igraph_from_edgelist(edge_list):
    
    n_vertices = max(max(edge_list))
    
    g = gr.Graph()
    
    g.add_vertices(n_vertices+1)
    
    g.add_edges(edge_list)
    
    return g

# %%
def calc_logic_vector(df, col, value):

    query_vector = value*np.ones(len(test_df))
    logic = df[col] == query_vector
    
    return logic

# %%
def find_correct_rows(df, edge_list):

    logical_indices = []
        
    for cur_pair in edge_list:
        
        cur_source = int(cur_pair[0])
        cur_target = int(cur_pair[1])
        
        source_logical_vector = calc_logic_vector(
                                df=df, col='Source', value=cur_source)
        
        target_logical_vector = calc_logic_vector(
                                df=df, col='Target', value=cur_target)
        
        combined_vector = source_logical_vector & target_logical_vector
        logical_indices.append(combined_vector)
        
    
    base_logical_vector = np.zeros(len(df)) == np.ones(len(df))
        
    for logical_index in logical_indices:
        base_logical_vector = base_logical_vector | logical_index
        
    return(base_logical_vector)

# %%
def get_raw_dataframe(decomp_graph, df):
    
    col = ['Filename','Nodes','Edges','Length']
    raw_dataframe = pd.DataFrame(columns=col)

    for every_graph in decomp_graph:
        cur_decomp_edgelist = every_graph.get_edgelist()
        cur_logic = find_correct_rows(df=df, edge_list=cur_decomp_edgelist)
        cur_nodes = gr.Graph.vcount(every_graph)
        cur_edges = gr.Graph.ecount(every_graph)
        cur_length = sum(df.loc[cur_logic].Length.values)

        cur_graph_dict = {'Filename': cur_filename, 'Nodes': cur_nodes, 
                          'Edges': cur_edges, 'Length': cur_length}

        new_rows = pd.DataFrame.from_dict([cur_graph_dict])

        raw_dataframe = raw_dataframe.append(new_rows)
        
        
    return raw_dataframe

# %% [markdown]
# %%pixie_debugger
#
#     decomp_graph = decomp_graph
#     df = test_df
#
#     col = ['Filename','Nodes','Edges','Length']
#     raw_dataframe = pd.DataFrame(columns=col)
#
#     for every_graph in decomp_graph:
#         cur_decomp_edgelist = every_graph.get_edgelist()
#         cur_logic = find_correct_rows(df=df, edge_list=cur_decomp_edgelist)
#         cur_nodes = gr.Graph.vcount(every_graph)
#         cur_edges = gr.Graph.ecount(every_graph)
#         cur_length = sum(df.loc[cur_logic].Length.values)
#
#         cur_graph_dict = {'Filename': cur_filename, 'Nodes': cur_nodes,
#                           'Edges': cur_edges, 'Length': cur_length}
#
#         new_rows = pd.DataFrame.from_dict([cur_graph_dict])
#
#         raw_dataframe = raw_dataframe.append(new_rows)

# %%
# Get the paths of the gnet files for processing

data_dir = '/Users/granthussey/github/MitoScripts/MitoScripts/data'
gnet_dfs = get_gnet_dfs(data_dir)

gnet_filenames = list(gnet_dfs.keys())

cur_filename = 'KRAS_mdivi_2W_001_000'

test_df = gnet_dfs[cur_filename]
test_df
# Out:
#      Source  Target   Length
# 0       522     517  0.41361
# 1       521     467  1.62278
# 2       520     466  0.83551
# 3       519     429  2.06772
# 4       518     425  6.27854
# ..      ...     ...      ...
# 531     215     178  1.40551
# 532     178      28  2.04729
# 533     139     169  3.08057
# 534     108      82  1.37558
# 535     118      99  2.70062
#
# [536 rows x 3 columns]

# %%
cur_edge_list = get_edge_list_from_df(test_df)
cur_edge_list
# Out:
# [[522, 517],
#  [521, 467],
#  [520, 466],
#  [519, 429],
#  [518, 425],
#  [516, 412],
#  [515, 372],
#  [514, 330],
#  [513, 482],
#  [512, 437],
#  [510, 432],
#  [509, 429],
#  [386, 427],
#  [508, 471],
#  [507, 354],
#  [506, 424],
#  [505, 468],
#  [503, 389],
#  [502, 500],
#  [501, 465],
#  [499, 349],
#  [498, 497],
#  [496, 270],
#  [494, 371],
#  [493, 492],
#  [372, 452],
#  [372, 370],
#  [491, 489],
#  [490, 334],
#  [488, 487],
#  [486, 368],
#  [485, 406],
#  [484, 483],
#  [481, 444],
#  [480, 479],
#  [478, 443],
#  [476, 402],
#  [475, 474],
#  [474, 396],
#  [474, 440],
#  [437, 358],
#  [437, 395],
#  [473, 391],
#  [472, 423],
#  [386, 390],
#  [427, 426],
#  [470, 469],
#  [464, 419],
#  [463, 419],
#  [462, 461],
#  [460, 345],
#  [459, 378],
#  [459, 415],
#  [459, 350],
#  [458, 307],
#  [457, 377],
#  [456, 454],
#  [455, 454],
#  [454, 453],
#  [451, 370],
#  [451, 371],
#  [452, 369],
#  [451, 233],
#  [450, 200],
#  [449, 297],
#  [448, 331],
#  [447, 294],
#  [446, 445],
#  [444, 400],
#  [444, 401],
#  [443, 399],
#  [442, 328],
#  [441, 362],
#  [440, 397],
#  [440, 398],
#  [439, 361],
#  [438, 325],
#  [393, 395],
#  [393, 357],
#  [436, 392],
#  [435, 394],
#  [434, 255],
#  [357, 324],
#  [357, 356],
#  [433, 359],
#  [390, 386],
#  [431, 429],
#  [430, 288],
#  [389, 391],
#  [428, 355],
#  [427, 426],
#  [427, 386],
#  [426, 425],
#  [422, 317],
#  [421, 251],
#  [420, 314],
#  [419, 383],
#  [418, 382],
#  [383, 160],
#  [417, 247],
#  [416, 350],
#  [416, 382],
#  [416, 312],
#  [415, 380],
#  [415, 279],
#  [348, 414],
#  [414, 346],
#  [414, 349],
#  [380, 379],
#  [379, 348],
#  [413, 307],
#  [413, 310],
#  [413, 188],
#  [411, 410],
#  [409, 175],
#  [371, 337],
#  [334, 367],
#  [367, 407],
#  [366, 365],
#  [406, 365],
#  [406, 296],
#  [405, 334],
#  [404, 403],
#  [403, 402],
#  [403, 293],
#  [402, 290],
#  [401, 400],
#  [400, 399],
#  [395, 358],
#  [393, 324],
#  [392, 288],
#  [392, 322],
#  [289, 323],
#  [391, 321],
#  [389, 356],
#  [388, 387],
#  [388, 388],
#  [385, 354],
#  [355, 319],
#  [355, 353],
#  [384, 319],
#  [383, 313],
#  [382, 314],
#  [381, 222],
#  [381, 163],
#  [381, 313],
#  [348, 130],
#  [348, 346],
#  [347, 310],
#  [380, 378],
#  [379, 309],
#  [345, 308],
#  [378, 343],
#  [377, 240],
#  [377, 242],
#  [341, 373],
#  [376, 342],
#  [375, 92],
#  [374, 338],
#  [372, 370],
#  [372, 235],
#  [337, 268],
#  [369, 299],
#  [369, 300],
#  [367, 265],
#  [366, 295],
#  [365, 262],
#  [364, 261],
#  [295, 295],
#  [363, 168],
#  [361, 360],
#  [361, 327],
#  [360, 325],
#  [360, 326],
#  [325, 326],
#  [358, 167],
#  [357, 356],
#  [356, 321],
#  [354, 353],
#  [353, 319],
#  [352, 317],
#  [314, 249],
#  [351, 312],
#  [351, 108],
#  [351, 280],
#  [311, 313],
#  [220, 130],
#  [350, 347],
#  [349, 216],
#  [348, 218],
#  [347, 276],
#  [346, 218],
#  [345, 186],
#  [344, 277],
#  [340, 301],
#  [340, 175],
#  [340, 338],
#  [339, 271],
#  [338, 236],
#  [337, 268],
#  [337, 335],
#  [336, 297],
#  [334, 298],
#  [333, 331],
#  [332, 201],
#  [331, 265],
#  [297, 142],
#  [295, 261],
#  [295, 260],
#  [329, 258],
#  [328, 326],
#  [328, 194],
#  [324, 292],
#  [289, 253],
#  [289, 321],
#  [320, 288],
#  [318, 316],
#  [317, 287],
#  [316, 286],
#  [316, 286],
#  [315, 251],
#  [314, 248],
#  [282, 226],
#  [282, 280],
#  [313, 222],
#  [312, 280],
#  [220, 159],
#  [311, 189],
#  [311, 246],
#  [276, 275],
#  [308, 274],
#  [308, 305],
#  [307, 239],
#  [212, 275],
#  [306, 273],
#  [304, 239],
#  [303, 271],
#  [270, 146],
#  [302, 177],
#  [92, 268],
#  [300, 202],
#  [300, 143],
#  [297, 264],
#  [296, 264],
#  [296, 139],
#  [259, 260],
#  [259, 198],
#  [294, 168],
#  [294, 198],
#  [257, 228],
#  [257, 292],
#  [292, 198],
#  [289, 254],
#  [286, 138],
#  [285, 192],
#  [284, 283],
#  [283, 249],
#  [283, 250],
#  [165, 165],
#  [165, 163],
#  [282, 191],
#  [281, 60],
#  [281, 247],
#  [246, 189],
#  [278, 243],
#  [278, 157],
#  [278, 189],
#  [216, 123],
#  [183, 273],
#  [123, 211],
#  [276, 213],
#  [275, 212],
#  [212, 238],
#  [273, 178],
#  [272, 177],
#  [272, 207],
#  [272, 120],
#  [271, 92],
#  [270, 207],
#  [269, 203],
#  [233, 171],
#  [267, 234],
#  [265, 232],
#  [266, 170],
#  [264, 263],
#  [261, 170],
#  [260, 229],
#  [259, 258],
#  [258, 199],
#  [228, 168],
#  [257, 227],
#  [256, 193],
#  [249, 248],
#  [248, 225],
#  [226, 138],
#  [247, 221],
#  [246, 180],
#  [189, 157],
#  [245, 155],
#  [244, 185],
#  [183, 215],
#  [243, 180],
#  [243, 127],
#  [215, 153],
#  [242, 182],
#  [242, 58],
#  [212, 238],
#  [241, 123],
#  [239, 213],
#  [238, 118],
#  [237, 214],
#  [235, 173],
#  [235, 204],
#  [146, 202],
#  [234, 144],
#  [234, 202],
#  [233, 143],
#  [142, 231],
#  [230, 86],
#  [228, 196],
#  [226, 190],
#  [163, 136],
#  [223, 166],
#  [222, 133],
#  [222, 162],
#  [220, 82],
#  [220, 130],
#  [108, 129],
#  [130, 129],
#  [219, 186],
#  [218, 217],
#  [186, 184],
#  [216, 185],
#  [183, 102],
#  [182, 187],
#  [180, 58],
#  [213, 149],
#  [211, 121],
#  [211, 179],
#  [210, 152],
#  [209, 152],
#  [179, 151],
#  [208, 207],
#  [206, 116],
#  [205, 175],
#  [203, 114],
#  [203, 172],
#  [173, 171],
#  [171, 91],
#  [143, 142],
#  [201, 113],
#  [142, 144],
#  [201, 90],
#  [170, 111],
#  [198, 168],
#  [197, 195],
#  [165, 166],
#  [191, 82],
#  [191, 137],
#  [190, 161],
#  [190, 161],
#  [161, 132],
#  [189, 127],
#  [189, 128],
#  [156, 158],
#  [156, 105],
#  [185, 103],
#  [183, 100],
#  [182, 40],
#  [123, 124],
#  [181, 129],
#  [180, 119],
#  [152, 153],
#  [179, 119],
#  [177, 120],
#  [176, 118],
#  [174, 173],
#  [171, 143],
#  [139, 140],
#  [166, 164],
#  [165, 136],
#  [165, 138],
#  [164, 135],
#  [164, 136],
#  [134, 132],
#  [134, 161],
#  [132, 81],
#  [158, 105],
#  [158, 106],
#  [129, 155],
#  [157, 103],
#  [156, 106],
#  [102, 105],
#  [102, 131],
#  [155, 125],
#  [153, 76],
#  [154, 122],
#  [153, 60],
#  [121, 120],
#  [121, 151],
#  [151, 96],
#  [150, 39],
#  [118, 144],
#  [148, 116],
#  [147, 114],
#  [92, 38],
#  [146, 94],
#  [145, 115],
#  [114, 88],
#  [143, 72],
#  [142, 112],
#  [110, 87],
#  [110, 141],
#  [138, 134],
#  [134, 132],
#  [82, 83],
#  [132, 80],
#  [130, 108],
#  [130, 104],
#  [128, 127],
#  [128, 63],
#  [103, 80],
#  [126, 106],
#  [125, 41],
#  [125, 101],
#  [123, 121],
#  [123, 122],
#  [122, 120],
#  [58, 97],
#  [119, 75],
#  [117, 55],
#  [116, 93],
#  [93, 38],
#  [93, 115],
#  [115, 93],
#  [113, 11],
#  [113, 72],
#  [112, 111],
#  [112, 72],
#  [111, 24],
#  [110, 35],
#  [84, 66],
#  [109, 67],
#  [82, 108],
#  [107, 81],
#  [105, 102],
#  [104, 101],
#  [104, 77],
#  [103, 43],
#  [102, 79],
#  [101, 77],
#  [100, 79],
#  [100, 78],
#  [98, 96],
#  [97, 56],
#  [97, 74],
#  [96, 73],
#  [95, 37],
#  [92, 27],
#  [92, 53],
#  [72, 52],
#  [90, 52],
#  [90, 51],
#  [89, 87],
#  [89, 23],
#  [89, 74],
#  [87, 35],
#  [85, 17],
#  [84, 44],
#  [84, 65],
#  [81, 80],
#  [79, 61],
#  [77, 41],
#  [60, 57],
#  [75, 54],
#  [75, 31],
#  [74, 54],
#  [71, 35],
#  [70, 24],
#  [69, 50],
#  [68, 19],
#  [44, 66],
#  [44, 47],
#  [66, 65],
#  [65, 64],
#  [62, 16],
#  [41, 59],
#  [54, 29],
#  [54, 29],
#  [52, 24],
#  [49, 7],
#  [48, 34],
#  [47, 34],
#  [47, 34],
#  [46, 18],
#  [45, 32],
#  [42, 40],
#  [40, 30],
#  [30, 37],
#  [38, 13],
#  [38, 30],
#  [37, 26],
#  [37, 12],
#  [36, 21],
#  [33, 2],
#  [29, 6],
#  [28, 15],
#  [28, 14],
#  [25, 10],
#  [22, 20],
#  [15, 14],
#  [15, 14],
#  [10, 8],
#  [10, 5],
#  [9, 4],
#  [8, 2],
#  [8, 5],
#  [5, 1],
#  [3, 2],
#  [0, 0],
#  [504, 425],
#  [511, 477],
#  [495, 408],
#  [452, 366],
#  [399, 443],
#  [390, 252],
#  [251, 281],
#  [401, 291],
#  [220, 108],
#  [188, 224],
#  [310, 188],
#  [215, 178],
#  [178, 28],
#  [139, 169],
#  [108, 82],
#  [118, 99]]

# %%
cur_graph = create_igraph_from_edgelist(cur_edge_list)
cur_graph

# %%
decomp_graph = gr.Graph.decompose(cur_graph)
decomp_graph
# Out:
# [<igraph.Graph at 0x114b655e8>,
#  <igraph.Graph at 0x114b656d8>,
#  <igraph.Graph at 0x114b657c8>,
#  <igraph.Graph at 0x114b658b8>,
#  <igraph.Graph at 0x114b659a8>,
#  <igraph.Graph at 0x114b65a98>,
#  <igraph.Graph at 0x114b65b88>,
#  <igraph.Graph at 0x114b65c78>,
#  <igraph.Graph at 0x114b65d68>,
#  <igraph.Graph at 0x114b65e58>,
#  <igraph.Graph at 0x114c2d048>,
#  <igraph.Graph at 0x114c2d138>,
#  <igraph.Graph at 0x114c2d228>,
#  <igraph.Graph at 0x114c2d318>,
#  <igraph.Graph at 0x114c2d408>,
#  <igraph.Graph at 0x114c2d4f8>,
#  <igraph.Graph at 0x114c2d5e8>,
#  <igraph.Graph at 0x114c2d6d8>,
#  <igraph.Graph at 0x114c2d7c8>,
#  <igraph.Graph at 0x114c2d8b8>,
#  <igraph.Graph at 0x114c2d9a8>,
#  <igraph.Graph at 0x114c2da98>,
#  <igraph.Graph at 0x114c2db88>,
#  <igraph.Graph at 0x114c2dc78>,
#  <igraph.Graph at 0x114c2dd68>,
#  <igraph.Graph at 0x114c2de58>,
#  <igraph.Graph at 0x114c2e048>,
#  <igraph.Graph at 0x114c2e138>,
#  <igraph.Graph at 0x114c2e228>,
#  <igraph.Graph at 0x114c2e318>,
#  <igraph.Graph at 0x114c2e408>,
#  <igraph.Graph at 0x114c2e4f8>,
#  <igraph.Graph at 0x114c2e5e8>,
#  <igraph.Graph at 0x114c2e6d8>,
#  <igraph.Graph at 0x114c2e7c8>,
#  <igraph.Graph at 0x114c2e8b8>,
#  <igraph.Graph at 0x114c2e9a8>,
#  <igraph.Graph at 0x114c2ea98>,
#  <igraph.Graph at 0x114c2eb88>,
#  <igraph.Graph at 0x114c2ec78>,
#  <igraph.Graph at 0x114c2ed68>,
#  <igraph.Graph at 0x114c2ee58>,
#  <igraph.Graph at 0x114c2f048>,
#  <igraph.Graph at 0x114c2f138>,
#  <igraph.Graph at 0x114c2f228>,
#  <igraph.Graph at 0x114c2f318>,
#  <igraph.Graph at 0x114c2f408>,
#  <igraph.Graph at 0x114c2f4f8>,
#  <igraph.Graph at 0x114c2f5e8>,
#  <igraph.Graph at 0x114c2f6d8>,
#  <igraph.Graph at 0x114c2f7c8>,
#  <igraph.Graph at 0x114c2f8b8>,
#  <igraph.Graph at 0x114c2f9a8>,
#  <igraph.Graph at 0x114c2fa98>,
#  <igraph.Graph at 0x114c2fb88>,
#  <igraph.Graph at 0x114c2fc78>,
#  <igraph.Graph at 0x114c2fd68>,
#  <igraph.Graph at 0x114c2fe58>,
#  <igraph.Graph at 0x114c30048>,
#  <igraph.Graph at 0x114c30138>,
#  <igraph.Graph at 0x114c30228>,
#  <igraph.Graph at 0x114c30318>,
#  <igraph.Graph at 0x114c30408>,
#  <igraph.Graph at 0x114c304f8>,
#  <igraph.Graph at 0x114c305e8>,
#  <igraph.Graph at 0x114c306d8>,
#  <igraph.Graph at 0x114c307c8>,
#  <igraph.Graph at 0x114c308b8>,
#  <igraph.Graph at 0x114c309a8>,
#  <igraph.Graph at 0x114c30a98>,
#  <igraph.Graph at 0x114c30b88>,
#  <igraph.Graph at 0x114c30c78>]

# %%
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000

# %%
def find_where(logic):
    A = [i for i, x in enumerate(logic) if x]
    return A

# %%
# %%pixie_debugger -b find_correct_rows
#
# get_raw_dataframe(decomp_graph=decomp_graph, df=test_df)
# Out:
# <script>
#     //Marker 8776273a
#     setTimeout(function(){
#         var cells=IPython.notebook.get_cells().filter(function(cell){
#             if(!cell.output_area || !cell.output_area.outputs){
#                 return false;
#             }
#             return cell.output_area.outputs.filter(function(output){
#                 if (output.output_type==="display_data"&&output.data&&output.data["text/html"]){
#                     return output.data["text/html"].includes("//Marker 8776273a")
#                 }
#                 return false;
#             }).length > 0;
#         });
#         if(cells.length>0){
#             var cell=cells[0];
#             var cellId=cell.cell_id;
#             var cellMetadata=cell._metadata.pixiedust;
#             var old_msg_id = cell.last_msg_id;
#             if (old_msg_id) {
#                 cell.kernel.clear_callbacks_for_msg(old_msg_id);
#             }
#             function getCellWidth(){
#                 try{
#                     return cell.input[0].clientWidth
#                 }catch(e){
#                     console.log(e)
#                 }
#             }
#             function getViewportHeight(){
#                 try {
#                     return document.documentElement.clientHeight
#                 } catch(e) {
#                     console.log(e)
#                 }
#             }
#             var snifferOptions = [{'nostore_cw':getCellWidth()},{'nostore_vh':getViewportHeight()},{'nostore_pixiedust':(typeof pixiedust != "undefined")}];
#
#                 snifferOptions.push({'org_params':'nostore_pixieapp,nostore_ispix,runInDialog,handlerId,nostore_pixiedust'});
#
#
#             user_options = { 'options': {
#                 'nostore_cw':getCellWidth(),
#                 'nostore_vh':getViewportHeight(),
#                 'nostore_pixiedust':(typeof pixiedust != "undefined"),
#                 'showchrome': 'true',
#                 'cell_id': cellId
#             }}
#
#                 user_options.options.org_params= 'nostore_pixieapp,nostore_ispix,runInDialog,handlerId,nostore_pixiedust';
#
#
#
#             function callback(){
#                 pixiedust.executeDisplay({"prefix": "8776273a", "command": "display(PixieDebugger_instance,nostore_pixieapp='PixieDebugger_instance',nostore_ispix='true',runInDialog='false',handlerId='pixiedust.apps.debugger.pixieDebugger_PixieDebugger_id',cell_id='cellId',nostore_pixiedust='true')", "entity": "PixieDebugger_instance", "options": {"nostore_pixieapp": "PixieDebugger_instance", "nostore_ispix": "true", "runInDialog": "false", "handlerId": "pixiedust.apps.debugger.pixieDebugger_PixieDebugger_id", "cell_id": "cellId", "nostore_pixiedust": "true"}, "sniffers": [], "avoidMetadata": false, "include_keys": ["filter"]},user_options);
#             }
#             if (typeof pixiedust == "undefined"){
#                 var s=document.getElementsByTagName('script')[0];
#                 var g=document.createElement('script');
#                 g.type='text/javascript';
#                 g.defer=true;
#                 g.async=true;
#                 var code = "var pixiedust = (function(){\n"+
# "    return {\n"+
# "        input_reply_queue: {\n"+
# "            inflight: null,\n"+
# "            queue: [],\n"+
# "            callbacks: {},\n"+
# "            counter: 0,\n"+
# "            registerCallback: function(cb){\n"+
# "                var handle = 'id_' + this.counter++;\n"+
# "                this.callbacks[handle] = cb;\n"+
# "                return \"$$\" + handle + \"$$\";\n"+
# "            },\n"+
# "            parseCallback: function(content){\n"+
# "                var match = content.text.match(/\\$\\$(.*)\\$\\$((.|\\n)*)/i);\n"+
# "                if (match){\n"+
# "                    content.text = match[2].trim();\n"+
# "                    if (!this.callbacks[match[1]]){\n"+
# "                        console.log(\"Cannot find callbacks for \" + match[1]);\n"+
# "                    }else{\n"+
# "                        var retValue = this.callbacks[match[1]];\n"+
# "                        delete this.callbacks[match[1]];\n"+
# "                        return retValue;\n"+
# "                    }\n"+
# "                }\n"+
# "                return null;\n"+
# "            }\n"+
# "        },\n"+
# "        getCell: function(cell_id){\n"+
# "            \n"+
# "            var cells=IPython.notebook.get_cells().filter(function(cell){\n"+
# "                return cell.cell_id==cell_id;\n"+
# "            });\n"+
# "            \n"+
# "            return cells.length>0?cells[0]:null;\n"+
# "        },\n"+
# "        \n"+
# "        executeDisplay:function(pd_ctls, user_ctls){\n"+
# "            var pd_controls = pd_ctls || {};\n"+
# "            var user_controls = user_ctls || {\"options\":{}};\n"+
# "            if (user_controls.inFlight){\n"+
# "                console.log(\"Ignoring request to execute Display that is already being executed\");\n"+
# "                return;\n"+
# "            }\n"+
# "            user_controls.inFlight = true;\n"+
# "            var options = $.extend({}, pd_controls.options || {}, user_controls.options || {} );\n"+
# "            function wrapDisplayDone(fn){\n"+
# "                return function(targetNode, targetNodeUpdated){\n"+
# "                    user_controls.inFlight = false;\n"+
# "                    if(targetNodeUpdated){\n"+
# "                        if (fn){\n"+
# "                            fn.apply(this);\n"+
# "                        }\n"+
# "                        $(document).trigger('pd_event', {type:\"pd_load\", targetNode: targetNode});\n"+
# "                    }\n"+
# "                }\n"+
# "            }\n"+
# "            user_controls.onDisplayDone = wrapDisplayDone( user_controls.onDisplayDone);\n"+
# "            var pd_prefix = pd_controls.prefix;\n"+
# "            var $targetDivId = user_controls.targetDivId;\n"+
# "            !function() {\n"+
# "    function getTargetNodeId(override=null){\n"+
# "        return override || $targetDivId || (\"wrapperHTML\"+ pd_prefix);\n"+
# "    }\n"+
# "    function getTargetNode(override=null){\n"+
# "        return $('#' + getTargetNodeId(override));\n"+
# "    }\n"+
# "    function checkRootInit(){\n"+
# "        node = getTargetNode();\n"+
# "        var retValue = node.is(\"[pd_init]\");\n"+
# "        if (retValue){\n"+
# "            node.removeAttr(\"pd_init\");\n"+
# "        }\n"+
# "        return retValue;\n"+
# "    }\n"+
# "    function setText(targetNode, contents, pdCtl = null, userCtl = null){\n"+
# "        var pd_elements = []\n"+
# "        targetNode.children().each(function(){\n"+
# "            if (this.tagName.toLowerCase().startsWith(\"pd_\")){\n"+
# "                pd_elements.push($(this).clone());\n"+
# "            }\n"+
# "        });\n"+
# "        if (!targetNode.hasClass(\"use_stream_output\")){\n"+
# "            targetNode.text(contents);\n"+
# "        }else{\n"+
# "            var consoleNode = targetNode.children(\"div.consoleOutput\");\n"+
# "            if (consoleNode.length == 0){\n"+
# "                consoleNode = targetNode.append('<div class=\"consoleOutput\"></div>').children(\"div.consoleOutput\");\n"+
# "            }\n"+
# "            var existing = consoleNode.text();\n"+
# "            if (existing != \"\"){\n"+
# "                contents = existing + \"\\n\" + contents;\n"+
# "            }\n"+
# "            consoleNode.html('<pre style=\"max-height: 300px;border: 1px lightgray solid;margin-top: 20px;\">' + contents + \"</pre>\");\n"+
# "        }\n"+
# "        if (pd_elements.length > 0 ){\n"+
# "            targetNode.append(pd_elements);\n"+
# "        }\n"+
# "        return true;\n"+
# "    }\n"+
# "    function setHTML(targetNode, contents, pdCtl = null, userCtl = null){\n"+
# "        var pd_elements = []\n"+
# "        targetNode.children().each(function(){\n"+
# "            var eltName = this.tagName.toLowerCase();\n"+
# "            if (eltName.startsWith(\"pd_\") || (eltName == \"div\" && this.classList.contains(\"consoleOutput\")) ){\n"+
# "                pd_elements.push($(this).clone());\n"+
# "            }\n"+
# "        });\n"+
# "        targetNode.html(\"<div pd_stop

# %%
# [i for i, x in enumerate(logic) if x]
